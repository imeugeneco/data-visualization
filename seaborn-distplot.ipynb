# %% [markdown]
# # Experimenting with Seaborn Displot

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
varx = np.random.randn(150)
varx
# Out:
# array([ 9.41190226e-01, -1.75482458e-01, -1.99507700e-01, -2.22618076e-01,
#        -2.65753031e-03,  1.25917607e+00,  2.37737567e-01, -1.40503172e-01,
#        -2.34137413e-02, -3.85608142e-01, -1.43163104e-01,  2.43483882e+00,
#        -3.14378403e-01,  8.41933857e-01,  4.82936270e-01,  4.95825620e-01,
#         5.13862645e-01, -2.06945816e-01,  2.32094490e-01,  2.11255309e+00,
#        -1.93726061e+00,  2.10200593e-01, -1.99299954e-01,  7.61621384e-02,
#         7.76714406e-02, -8.45614511e-01, -3.32125523e-01,  1.34383975e+00,
#        -1.02750485e-01, -1.97471336e+00, -6.00935002e-01,  4.59201444e-01,
#         4.94353391e-01,  1.36955832e+00, -7.54307553e-01, -9.88435309e-01,
#         1.57965193e+00, -1.15131131e+00, -1.29760050e+00,  2.08040141e-01,
#        -4.08023036e-01,  1.22367205e+00,  2.44994638e+00, -5.17504179e-01,
#         2.46088331e-01,  1.01537234e+00, -9.23691877e-01,  4.10649820e-01,
# ...

# %%
sns.set()
sns.distplot(varx, color='red')

# %%
label_dist = pd.Series(varx, name='variable x')

# %%
sns.distplot(label_dist)

# %%
sns.distplot(label_dist, vertical=True, color='green', hist=False)

# %%
sns.distplot(label_dist, color='gray', rug=True)

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
sns.distplot(flights['passengers'], rug=True, color='purple')

# %%
sns.distplot(flights['passengers'].value_counts())

# %%
flights['passengers'].describe()
# Out:
# count    144.000000
# mean     280.298611
# std      119.966317
# min      104.000000
# 25%      180.000000
# 50%      265.500000
# 75%      360.500000
# max      622.000000
# Name: passengers, dtype: float64

# %%
for row in flights.loc:
    print(flights.loc[row, 'passengers'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-62310f815e94> in <module>
#       1 for row in flights.loc:
# ----> 2     print(flights.loc[row, 'passengers'])
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
# ...
